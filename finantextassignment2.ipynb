# %% [markdown]
# <a href="https://colab.research.google.com/github/zaku2590/finantext/blob/main/finantextassignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

path = '/content/'

df = pd.read_csv(path + 'transaction.csv')
display(df.shape[0])
display(df.info())
display(df.head(10))
display(df.isnull().sum())
# Out:
# 261000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261000 entries, 0 to 260999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    261000 non-null  object
#  1   id      261000 non-null  int64
#  2   amount  261000 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 6.0+ MB
# None
#       date   id  amount
# 0  2021-06  717   39888
# 1  2015-11   42    8424
# 2  2016-01  531    5351
# 3  2017-11  855    9033
# 4  2021-07  238   44693
# 5  2019-03  277    9174
# 6  2015-06  543    8515
# 7  2021-05  426    1452
# 8  2021-10  372   22395
# 9  2019-10   98    8697
# date      0
# id        0
# amount    0
# dtype: int64

# %%
upper_limit = df['amount'].quantile(0.99)

plt.figure(figsize=(10, 5))
plt.hist(df[df['amount'] <= upper_limit]['amount'], bins=50, color='skyblue', edgecolor='black')
plt.title('Trimmed Distribution of Transaction Amounts')
plt.xlabel('Amount (JPY)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# 外れ値を除外したヒストグラムでは、決済金額が数千円〜1万円未満の範囲に集中していることが確認できた。
# 特に少額決済（1000〜5000円程度）が多く、日常的な消費活動（飲食、小売など）が主な利用用途と考えられる。
# 高額決済は全体のごく一部であり、カード利用の主な傾向は日常支出に集中しているといえる。
